# %%
import numpy as np
import os
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
import matplotlib.pyplot as plt
from keras.models import Model
from keras import layers
from keras.layers import Input, Conv2D, BatchNormalization, MaxPool2D, Activation, Flatten, Dense, Dropout

# %%
from sklearn.model_selection import train_test_split
data_train = pd.read_csv('fashion-mnist_train.csv')
X_full = data_train.iloc[:,1:]
y_full = data_train.iloc[:,:1]
x_train, x_test, y_train, y_test = train_test_split(X_full, y_full, test_size
= 0.3)

x_train = x_train.values.reshape(-1, 28, 28, 1).astype('float32') / 255
x_test = x_test.values.reshape(-1, 28, 28, 1).astype('float32') / 255
y_train = y_train.values.astype('int')
y_test = y_test.values.astype('int')
print('Training', x_train.shape, x_train.max())
print('Testing', x_test.shape, x_test.max())
# Out:
# Training (3313, 28, 28, 1) nan
# Testing (1420, 28, 28, 1) 1.0

# %%
# reorganize by groups
train_groups = [x_train[np.where(y_train==i)[0]] for i in np.unique(y_train)]
test_groups = [x_test[np.where(y_test==i)[0]] for i in np.unique(y_train)]
print('train groups:', [x.shape[0] for x in train_groups])
print('test groups:', [x.shape[0] for x in test_groups])
# Out:
# train groups: [355, 332, 336, 338, 318, 316, 350, 320, 302, 346]
# test groups: [126, 147, 133, 140, 151, 145, 130, 170, 152, 126]

# %%
def gen_random_batch(in_groups, batch_halfsize = 8):
  out_img_a, out_img_b, out_score = [], [], []
  all_groups = list(range(len(in_groups)))
  for match_group in [True, False]:
    group_idx = np.random.choice(all_groups, size = batch_halfsize)
    out_img_a += [in_groups[c_idx]
    [np.random.choice(range(in_groups[c_idx].shape[0]))] for c_idx in group_idx]
    if match_group:
      b_group_idx = group_idx
      out_score += [1]*batch_halfsize
    else:
      # anything but the same group
      non_group_idx = [np.random.choice([i for i in all_groups if i!=c_idx]) 
                                                    for c_idx in group_idx]
      b_group_idx = non_group_idx
      out_score += [0]*batch_halfsize
    out_img_b += [in_groups[c_idx]
    [np.random.choice(range(in_groups[c_idx].shape[0]))] for c_idx in b_group_idx]
  return np.stack(out_img_a,0), np.stack(out_img_b,0), np.stack(out_score,0)

# %%
pv_a, pv_b, pv_sim = gen_random_batch(train_groups, 3)
fig, m_axs = plt.subplots(2, pv_a.shape[0], figsize = (12, 6))
for c_a, c_b, c_d, (ax1, ax2) in zip(pv_a, pv_b, pv_sim, m_axs.T):
  ax1.imshow(c_a[:,:,0])
  ax1.set_title('Image A')
  ax1.axis('off')
  ax2.imshow(c_b[:,:,0])
  ax2.set_title('Image B\n Similarity: %3.0f%%' % (100*c_d))
  ax2.axis('off')

# %%
def conv2D_bn_relu(x, filters, kernel_size, strides, padding='valid', kernel_initializer='glorot_uniform', name=None):

    x = layers.Conv2D(filters=filters, 
                      kernel_size=kernel_size, 
                      strides=strides, 
                      padding=padding, 
                      kernel_initializer=kernel_initializer,
                      name=name,
                      use_bias=False)(x)
    x = layers.BatchNormalization(scale=False)(x)
    return layers.Activation('relu')(x)


def inception_module_A(x, filters=None, kernel_initializer='glorot_uniform'):
    
    if filters is None:
        filters = int(x.shape[-1])
    branch_filters = filters // 4
        
    b1 = conv2D_bn_relu(x, 
                        filters=(branch_filters // 3) * 2, 
                        kernel_size=1, 
                        strides=1, 
                        kernel_initializer=kernel_initializer)
    b1 = conv2D_bn_relu(b1, 
                        filters=branch_filters, 
                        kernel_size=3, 
                        strides=1, 
                        padding='same', 
                        kernel_initializer=kernel_initializer)
    
    b2 = conv2D_bn_relu(x, 
                        filters=(branch_filters // 3) * 2, 
                        kernel_size=1, 
                        strides=1, 
                        kernel_initializer=kernel_initializer)
    b2 = conv2D_bn_relu(b2, 
                        filters=branch_filters, 
                        kernel_size=3, 
                        strides=1, 
                        padding='same', 
                        kernel_initializer=kernel_initializer)
    b2 = conv2D_bn_relu(b2, 
                        filters=branch_filters, 
                        kernel_size=3, 
                        strides=1, 
                        padding='same', 
                        kernel_initializer=kernel_initializer)
        
    b3 = conv2D_bn_relu(x, 
                        filters=branch_filters, 
                        kernel_size=1, 
                        strides=1, 
                        kernel_initializer=kernel_initializer)
    
    pool = layers.AveragePooling2D(pool_size=(3, 3), strides=1, padding='same')(x)
    pool = conv2D_bn_relu(pool, 
                          filters=branch_filters, 
                          kernel_size=1, 
                          strides=1, 
                          kernel_initializer=kernel_initializer)

    return layers.concatenate([b1, b2, b3, pool])


def inception_module_C(x, filters=None, kernel_initializer='glorot_uniform'):  
    if filters is None:
        filters = int(x.shape[-1])
    branch_filters = filters // 6
        
    b1 = conv2D_bn_relu(x, 
                        filters=(branch_filters // 2) * 3, 
                        kernel_size=1, 
                        strides=1, 
                        kernel_initializer=kernel_initializer)
        
    b1a = conv2D_bn_relu(b1, 
                         filters=branch_filters, 
                         kernel_size=(1, 3), 
                         strides=1, 
                         padding='same', 
                         kernel_initializer=kernel_initializer)
    
    b1b = conv2D_bn_relu(b1, 
                         filters=branch_filters, 
                         kernel_size=(3, 1), 
                         strides=1, 
                         padding='same', 
                         kernel_initializer=kernel_initializer)
    
    b2 = conv2D_bn_relu(x, 
                        filters=(branch_filters // 2) * 3, 
                        kernel_size=1, 
                        strides=1, 
                        kernel_initializer=kernel_initializer)
    b2 = conv2D_bn_relu(b2, 
                        filters=(branch_filters // 4) * 7, 
                        kernel_size=(1, 3), 
                        strides=1, 
                        padding='same', 
                        kernel_initializer=kernel_initializer)
    b2 = conv2D_bn_relu(b2, 
                        filters=branch_filters * 2, 
                        kernel_size=(3, 1), 
                        strides=1, 
                        padding='same', 
                        kernel_initializer=kernel_initializer)

    b2a = conv2D_bn_relu(b2, 
                         filters=branch_filters, 
                         kernel_size=(1, 3), 
                         strides=1, 
                         padding='same', 
                         kernel_initializer=kernel_initializer)
    
    b2b = conv2D_bn_relu(b2, 
                         branch_filters, 
                         kernel_size=(3, 1), 
                         strides=1, 
                         padding='same', 
                         kernel_initializer=kernel_initializer)
        
    b3 = conv2D_bn_relu(x, 
                        filters=branch_filters, 
                        kernel_size=1, 
                        strides=1, 
                        kernel_initializer=kernel_initializer)
    
    pool = layers.AveragePooling2D(pool_size=(3, 3), strides=1, padding='same')(x)
    pool = conv2D_bn_relu(pool, 
                          filters=branch_filters, 
                          kernel_size=1, 
                          strides=1, 
                          kernel_initializer=kernel_initializer)
    
    return layers.concatenate([b1a, b1b, b2a, b2b, b3, pool])


def reduction_module_A(x, filters, kernel_initializer='glorot_uniform'):

    branch_filters = (filters - int(x.shape[-1])) // 2
        
    b1 = conv2D_bn_relu(x, 
                        filters=branch_filters, 
                        kernel_size=3, 
                        strides=2, 
                        padding='same', 
                        kernel_initializer=kernel_initializer)
    
    b2 = conv2D_bn_relu(x, 
                        filters=(branch_filters // 3) * 2, 
                        kernel_size=1, 
                        strides=1, 
                        kernel_initializer=kernel_initializer)
    b2 = conv2D_bn_relu(b2, 
                        filters=(branch_filters // 6) * 5, 
                        kernel_size=3, 
                        strides=1, 
                        padding='same', 
                        kernel_initializer=kernel_initializer)
    b2 = conv2D_bn_relu(b2, 
                        filters=branch_filters, 
                        kernel_size=3, 
                        strides=2, 
                        padding='same', 
                        kernel_initializer=kernel_initializer)
    
    pool = layers.MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(x)

    return layers.concatenate([b1, b2, pool])

# %%
stem_width = 128

inputs = layers.Input(shape=x_train.shape[1:])
x = conv2D_bn_relu(inputs,
                   filters=stem_width,
                   kernel_size=5,
                   strides=1,
                   padding='same',
                   name='conv_1')

x = reduction_module_A(x, filters=int(2*stem_width))
x = layers.SpatialDropout2D(0.3)(x)

x = inception_module_A(x, filters=int(2*stem_width))
x = inception_module_A(x, filters=int(2*stem_width))

x = reduction_module_A(x, filters=int(3*stem_width))
x = layers.SpatialDropout2D(0.5)(x)

x = inception_module_C(x, filters=int(3*stem_width))
x = inception_module_C(x, filters=int(3*stem_width))
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(32)(x)
# x = layers.Activation('softmax', name='softmax')(x)

model = Model(inputs=inputs, outputs=x)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv_1 (Conv2D)                (None, 28, 28, 128)  3200        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 28, 28, 128)  384        ['conv_1[0][0]']
#  alization)
#
#  activation (Activation)        (None, 28, 28, 128)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 42)   5376        ['activation[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 42)  126         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 28, 28, 42)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 50)   18900       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 50)  150         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 28, 28, 50)   0           ['batch_normalization_3[0][0]']
#
#  conv2d (Conv2D)                (None, 14, 14, 64)   73728       ['activation[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 14, 14, 64)   28800       ['activation_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 14, 14, 64)  192         ['conv2d[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 14, 14, 64)  192         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 14, 14, 64)   0           ['batch_normalization_1[0][0]']
#
#  activation_4 (Activation)      (None, 14, 14, 64)   0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 14, 14, 128)  0           ['activation[0][0]']
#
#  concatenate (Concatenate)      (None, 14, 14, 256)  0           ['activation_1[0][0]',
#                                                                   'activation_4[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  spatial_dropout2d (SpatialDrop  (None, 14, 14, 256)  0          ['concatenate[0][0]']
#  out2D)
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 42)   10752       ['spatial_dropout2d[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 14, 14, 42)  126         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 14, 14, 42)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 14, 14, 42)   10752       ['spatial_dropout2d[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 64)   24192       ['activation_7[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 14, 14, 42)  126         ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 14, 14, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 14, 14, 42)   0           ['batch_normalization_5[0][0]']
#
#  activation_8 (Activation)      (None, 14, 14, 64)   0           ['batch_normalization_8[0][0]']
#
#  average_pooling2d (AveragePool  (None, 14, 14, 256)  0          ['spatial_dropout2d[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 64)   24192       ['activation_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 64)   36864       ['activation_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 14, 14, 64)   16384       ['spatial_dropout2d[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 14, 14, 64)   16384       ['average_pooling2d[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 14, 14, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 14, 14, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 14, 14, 64)  192         ['conv2d_9[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 14, 14, 64)  192         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_6 (Activation)      (None, 14, 14, 64)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 14, 14, 64)   0           ['batch_normalization_9[0][0]']
#
#  activation_10 (Activation)     (None, 14, 14, 64)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 14, 14, 64)   0           ['batch_normalization_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 14, 14, 256)  0           ['activation_6[0][0]',
#                                                                   'activation_9[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 14, 14, 42)   10752       ['concatenate_1[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 14, 14, 42)  126         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 14, 14, 42)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 14, 14, 42)   10752       ['concatenate_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 14, 14, 64)   24192       ['activation_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 14, 14, 42)  126         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 14, 14, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 14, 14, 42)   0           ['batch_normalization_12[0][0]']
#
#  activation_15 (Activation)     (None, 14, 14, 64)   0           ['batch_normalization_15[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 14, 14, 256)  0          ['concatenate_1[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 14, 14, 64)   24192       ['activation_12[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 64)   36864       ['activation_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 64)   16384       ['concatenate_1[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 14, 14, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 14, 14, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 14, 14, 64)  192         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 14, 14, 64)  192         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 14, 14, 64)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 14, 14, 64)   0           ['batch_normalization_16[0][0]']
#
#  activation_17 (Activation)     (None, 14, 14, 64)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 14, 14, 64)   0           ['batch_normalization_18[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 256)  0           ['activation_13[0][0]',
#                                                                   'activation_16[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 42)   10752       ['concatenate_2[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 42)  126         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 14, 14, 42)   0           ['batch_normalization_20[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 50)   18900       ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 50)  150         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 14, 14, 50)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 7, 7, 64)     147456      ['concatenate_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 7, 7, 64)     28800       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 7, 7, 64)    192         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 7, 7, 64)    192         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_22[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 256)   0           ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 7, 7, 384)    0           ['activation_19[0][0]',
#                                                                   'activation_22[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  spatial_dropout2d_1 (SpatialDr  (None, 7, 7, 384)   0           ['concatenate_3[0][0]']
#  opout2D)
#
#  conv2d_25 (Conv2D)             (None, 7, 7, 96)     36864       ['spatial_dropout2d_1[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 7, 7, 96)    288         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 7, 7, 96)     0           ['batch_normalization_26[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 7, 7, 112)    32256       ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 7, 7, 112)   336         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 7, 7, 112)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 7, 7, 96)     36864       ['spatial_dropout2d_1[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 7, 7, 128)    43008       ['activation_27[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 7, 7, 96)    288         ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 7, 7, 128)   384         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 7, 7, 96)     0           ['batch_normalization_23[0][0]']
#
#  activation_28 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_28[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 7, 7, 384)   0           ['spatial_dropout2d_1[0][0]']
#  oling2D)
#
#  conv2d_23 (Conv2D)             (None, 7, 7, 64)     18432       ['activation_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 7, 7, 64)     18432       ['activation_23[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 7, 7, 64)     24576       ['activation_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 64)     24576       ['activation_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 64)     24576       ['spatial_dropout2d_1[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 64)     24576       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 7, 7, 64)    192         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 7, 7, 64)    192         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 7, 7, 64)    192         ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 7, 7, 64)    192         ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 7, 7, 64)    192         ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 7, 7, 64)    192         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_25[0][0]']
#
#  activation_29 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_29[0][0]']
#
#  activation_30 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_30[0][0]']
#
#  activation_31 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_31[0][0]']
#
#  activation_32 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_32[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 7, 7, 384)    0           ['activation_24[0][0]',
#                                                                   'activation_25[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'activation_30[0][0]',
#                                                                   'activation_31[0][0]',
#                                                                   'activation_32[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 7, 7, 96)     36864       ['concatenate_4[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 7, 7, 96)    288         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 7, 7, 96)     0           ['batch_normalization_36[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 7, 7, 112)    32256       ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 7, 7, 112)   336         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 7, 7, 112)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 96)     36864       ['concatenate_4[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 7, 7, 128)    43008       ['activation_37[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 7, 7, 96)    288         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 7, 7, 128)   384         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 7, 7, 96)     0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_38[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 7, 7, 384)   0           ['concatenate_4[0][0]']
#  oling2D)
#
#  conv2d_33 (Conv2D)             (None, 7, 7, 64)     18432       ['activation_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 7, 7, 64)     18432       ['activation_33[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 7, 7, 64)     24576       ['activation_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 7, 7, 64)     24576       ['activation_38[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 7, 7, 64)     24576       ['concatenate_4[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 7, 7, 64)     24576       ['average_pooling2d_3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 7, 7, 64)    192         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 7, 7, 64)    192         ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 7, 7, 64)    192         ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 7, 7, 64)    192         ['conv2d_39[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 7, 7, 64)    192         ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 7, 7, 64)    192         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_34[0][0]']
#
#  activation_35 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_35[0][0]']
#
#  activation_39 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_39[0][0]']
#
#  activation_40 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_40[0][0]']
#
#  activation_41 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_41[0][0]']
#
#  activation_42 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_42[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 7, 7, 384)    0           ['activation_34[0][0]',
#                                                                   'activation_35[0][0]',
#                                                                   'activation_39[0][0]',
#                                                                   'activation_40[0][0]',
#                                                                   'activation_41[0][0]',
#                                                                   'activation_42[0][0]']
#
#  global_average_pooling2d (Glob  (None, 384)         0           ['concatenate_5[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 384)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 32)           12320       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1,204,616
# Trainable params: 1,198,600
# Non-trainable params: 6,016
# __________________________________________________________________________________________________

# %%
from keras.layers import concatenate

img_a_in = Input(shape = x_train.shape[1:], name = 'ImageA_Input')
img_b_in = Input(shape = x_train.shape[1:], name = 'ImageB_Input')

img_a_feat = model(img_a_in)
img_b_feat = model(img_b_in)

combined_features = concatenate([img_a_feat, img_b_feat], name =
'merge_features')
combined_features = Dense(16, activation = 'linear')(combined_features)
combined_features = BatchNormalization()(combined_features)
combined_features = Activation('relu')(combined_features)
combined_features = Dense(4, activation = 'linear')(combined_features)
combined_features = BatchNormalization()(combined_features)
combined_features = Activation('relu')(combined_features)
combined_features = Dense(1, activation = 'sigmoid')(combined_features)
similarity_model = Model(inputs = [img_a_in, img_b_in], outputs =
[combined_features], name = 'Similarity_Model')
similarity_model.summary()
# Out:
# Model: "Similarity_Model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  ImageA_Input (InputLayer)      [(None, 28, 28, 1)]  0           []
#
#  ImageB_Input (InputLayer)      [(None, 28, 28, 1)]  0           []
#
#  model (Functional)             (None, 32)           1204616     ['ImageA_Input[0][0]',
#                                                                   'ImageB_Input[0][0]']
#
#  merge_features (Concatenate)   (None, 64)           0           ['model[0][0]',
#                                                                   'model[1][0]']
#
#  dense_1 (Dense)                (None, 16)           1040        ['merge_features[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 16)          64          ['dense_1[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 16)           0           ['batch_normalization_43[0][0]']
#
#  dense_2 (Dense)                (None, 4)            68          ['activation_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 4)           16          ['dense_2[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 4)            0           ['batch_normalization_44[0][0]']
#
#  dense_3 (Dense)                (None, 1)            5           ['activation_44[0][0]']
#
# ==================================================================================================
# Total params: 1,205,809
# Trainable params: 1,199,753
# Non-trainable params: 6,056
# __________________________________________________________________________________________________

# %%
similarity_model.compile(optimizer='adam', loss = 'binary_crossentropy',
metrics = ['mae'])

# %%
def show_model_output(nb_examples = 3):
  pv_a, pv_b, pv_sim = gen_random_batch(test_groups, nb_examples)
  pred_sim = similarity_model.predict([pv_a, pv_b])
  fig, m_axs = plt.subplots(2, pv_a.shape[0], figsize = (12, 6))
  for c_a, c_b, c_d, p_d, (ax1, ax2) in zip(pv_a, pv_b, pv_sim, pred_sim,
  m_axs.T):
    ax1.imshow(c_a[:,:,0])
    ax1.set_title('Image A\n Actual: %3.0f%%' % (100*c_d))
    ax1.axis('off')
    ax2.imshow(c_b[:,:,0])
    ax2.set_title('Image B\n Predicted: %3.0f%%' % (100*p_d))
    ax2.axis('off')
  return fig
  # a completely untrained model
_ = show_model_output()

# %%
# make a generator out of the data
def siam_gen(in_groups, batch_size = 32):
  while True:
    pv_a, pv_b, pv_sim = gen_random_batch(train_groups, batch_size//2)
    yield [pv_a, pv_b], pv_sim

valid_a, valid_b, valid_sim = gen_random_batch(test_groups, 1024)
loss_history = similarity_model.fit(siam_gen(train_groups),
steps_per_epoch = 500,
validation_data=([valid_a, valid_b],
valid_sim),
epochs = 10,
verbose = True)

# %%
_ = show_model_output()

# %%
x_test_features = model.predict(x_test, verbose = True,
batch_size=128)

# %%
# %%time
from sklearn.manifold import TSNE
tsne_obj = TSNE(n_components=2,
init='pca',
random_state=101,
method='barnes_hut',
n_iter=500,
verbose=2)
tsne_features = tsne_obj.fit_transform(x_test_features)

# %%
obj_categories = ['T-shirt/top','Trouser','Pullover','Dress',
'Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot'
]
colors = plt.cm.rainbow(np.linspace(0, 1, 10))
plt.figure(figsize=(10, 10))

for c_group, (c_color, c_label) in enumerate(zip(colors, obj_categories)):
  plt.scatter(tsne_features[np.where(y_test == c_group), 0],
  tsne_features[np.where(y_test == c_group), 1],
  marker='o',
  color=c_color,
  linewidth='1',
  alpha=0.8,
  label=c_label)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE on Testing Samples')
plt.legend(loc='best')
plt.savefig('clothes-dist.png')
plt.show(block=False)
